# %%
from packages import *

# %%
df = pd.read_csv('./data/kc_house_data.csv')
# %store df
df
# Out:
# Stored 'df' (DataFrame)
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# |category|field|description|
# |-------|----|:-----------|
# |id| id |Unique ID for each home sold|
# |time| date | Date of the home sale|
# |price| price | Price of each home sold|
# |setup| bedrooms | Number of bedrooms|
# |setup| bathrooms | Number of bathrooms, where .5 accounts for a room with a toilet but no shower|
# |setup| sqft_living | Square footage of the apartments interior living space|
# |setup| sqft_lot | Square footage of the land space|
# |setup| floors | Number of floors|
# |especial setup| waterfront | A dummy variable for whether the apartment was overlooking the waterfront or not|
# |score| view | An index from 0 to 4 of how good the view of the property was|
# |score| condition | An index from 1 to 5 on the condition of the apartment,|
# |score| grade | An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design.|
# |setup| sqft_above | The square footage of the interior housing space that is above ground level|
# |setup| sqft_basement | The square footage of the interior housing space that is below ground level|
# |setup| yr_built | The year the house was initially built|
# |setup| yr_renovated | The year of the house’s last renovation|
# |position| zipcode | What zipcode area the house is in|
# |position| lat | Lattitude|
# |position| long | Longitude|
# |setup| sqft_living15 | The square footage of interior housing living space for the nearest 15 neighbors|
# |setup| sqft_lot15 | The square footage of the land lots of the nearest 15 neighbors|

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.hist(bins=20, figsize=(16,12))
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'date'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>],
#        [<AxesSubplot:title={'center':'sqft_living'}>,
#         <AxesSubplot:title={'center':'sqft_lot'}>,
#         <AxesSubplot:title={'center':'floors'}>,
#         <AxesSubplot:title={'center':'waterfront'}>,
#         <AxesSubplot:title={'center':'view'}>],
#        [<AxesSubplot:title={'center':'condition'}>,
#         <AxesSubplot:title={'center':'grade'}>,
#         <AxesSubplot:title={'center':'sqft_above'}>,
#         <AxesSubplot:title={'center':'sqft_basement'}>,
#         <AxesSubplot:title={'center':'yr_built'}>],
#        [<AxesSubplot:title={'center':'yr_renovated'}>,
#         <AxesSubplot:title={'center':'zipcode'}>,
#         <AxesSubplot:title={'center':'lat'}>,
#         <AxesSubplot:title={'center':'long'}>,
# ...
